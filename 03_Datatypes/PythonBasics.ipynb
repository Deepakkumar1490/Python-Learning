# %%
x = 5/4
print(x)
x = 6/4
print(x)
x = 7/4
print(x)

x = 5//4
print(x)
x = 6//4
print(x)
x = 7//4
print(x)
# Out:
# 1.25
# 1.5
# 1.75
# 1
# 1
# 1

# %%
x  = 26 % 8
print(x)
# Out:
# 2

# %%
# arithmetic expression operation rules
print((4 + 5) * 6)
print(2 ** 3 + 1)
print(1 + 2 **3)
print((1 + 2) ** 3)
print( 2 + 4+ 6)
# Out:
# 54
# 9
# 9
# 27
# 12

# %%
# expressions produce errors

# print(2 +) invalid syntax
print(42)
print(((3 + 1) * 2))
# print(((3 + 1 * 2)) _IncompleteInputError: incomplete input
print(0)
# print( 1 + 2 3) SyntaxError: invalid syntax. Perhaps you forgot a comma?
# Out:
# 42
# 8
# 0

# %%
# String Concatenation and Replication

print('Hello' + 'Hello' + 'Hello')
print('Hello' * 3)
print(3 * 'Hello')
print((2 + 2) * 'Hello')
print('12' + '12')
# Out:
# HelloHelloHello
# HelloHelloHello
# HelloHelloHello
# HelloHelloHelloHello
# 1212

# %%
# String Concatenation and Replication, what error occurs?

# print('yes no) SyntaxError: unterminated string literal (detected at line 1)
# print('Hello' * 3.0) TypeError: can't multiply sequence by non-int of type 'float'
# print('Hello' + 3) TypeError: can only concatenate str (not "int") to str
# print(Hello + Hello + Hello) NameError: name 'Hello' is not defined
# print("Alice" * "Bob") TypeError: can't multiply sequence by non-int of type 'str'
# print('Hello' / 5) TypeError: unsupported operand type(s) for /: 'str' and 'int'
# print('Hello' / 'Hello') TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
# Storing Values in Variables

nephew = 'Jack'
print(nephew)

nephew = 'Jack'
print('nephew') # without a quote, python looks for a variable. Wiht quotes python accepts it as a just text string

nephew = 'Jack'
nephew = 'Albert'
print(nephew)

nephew = 'Jack'
Nephew = 'Albert'
print(nephew)
# Out:
# Jack
# nephew
# Albert
# Jack

# %%
# Storing Values in Variables, what error cause?

# nephew = Jack -> NameError: name 'Jack' is not defined
# print(nephew)

# nephew = 'Jack' -> NameError: name 'Jack' is not defined
# print(Jack) 

# nephew = 'Jack' -> NameError: name 'NEPHEW' is not defined
# print(NEPHEW)

# %%
# type casting

print(int("42"))
# print(int("forty two")) -> ValueError: invalid literal for int() with base 10: 'forty two'
# print(int('Hello')) -> ValueError: invalid literal for int() with base 10: 'Hello'
print(int(-42))
print(int(3.1415))
print(int(3.7415))
print(int(3.5415))
print(float(-42))
print(str(-42))
print(str(3.1415))
print(str('Hello'))
print(str(float(int(3.14))))
print(str(3))
print(str(3.0))
# Out:
# 42
# -42
# 3
# 3
# 3
# -42.0
# -42
# 3.1415
# Hello
# 3.0
# 3
# 3.0

# %%
number_of_cats = 4
# print('I have'+ number_of_cats) TypeError: can only concatenate str (not "int") to str

# %%
print(round(4.9))
print(abs(5))
print(abs(-5))
# Out:
# 5
# 5
# 5

# %%
len_of_rectangle = int(input("Enter the length of rectangle"))
print("O" * len_of_rectangle)
print("O" * len_of_rectangle)
print("O" * len_of_rectangle)
print("O" * len_of_rectangle)
print("O" * len_of_rectangle)
# Out:
# OOOOO
# OOOOO
# OOOOO
# OOOOO
# OOOOO

# %%
width = int(input("Enter the width for the rectangle:"))
length = int(input("Enter the length for the rectangle:"))
print("Area of the rectangle:", (width * length))
print("Perimeter of the rectangle:", ((2 * width) + (2 * length)))
# Out:
# Area of the rectangle: 45
# Perimeter of the rectangle: 28
