# %%
height = 26.6

# %%
height
# Out:
# 26.6

# %%
type(height)
# Out:
# float

# %%
number = 1
decimal = 1.2
print(number + decimal) 
print(number - decimal)
print(number * decimal)
print(number / decimal)
# Out:
# 2.2
# -0.19999999999999996
# 1.2
# 0.8333333333333334

# %%
number = 1.2
decimal = 1.2
print(number + decimal)
print(number - decimal)
print(number * decimal)
print(number / decimal)
# Out:
# 2.4
# 0.0
# 1.44
# 1.0

# %%
temperature = float(36.5)       # float() fun for storing the data
print(temperature)
type(temperature)
# Out:
# 36.5
# float
